# %%
# Documentation: https://cloud.ibm.com/docs/text-to-speech?topic=text-to-speech-voices

# %% [markdown]
# # 0. Install Dependencies

# %%
# !pip install ibm_watson
# Out:
# Requirement already satisfied: ibm_watson in /usr/local/lib/python3.10/dist-packages (8.1.0)
# Requirement already satisfied: requests<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from ibm_watson) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from ibm_watson) (2.8.2)
# Requirement already satisfied: websocket-client>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from ibm_watson) (1.8.0)
# Requirement already satisfied: ibm-cloud-sdk-core==3.*,>=3.3.6 in /usr/local/lib/python3.10/dist-packages (from ibm_watson) (3.22.0)
# Requirement already satisfied: urllib3<3.0.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from ibm-cloud-sdk-core==3.*,>=3.3.6->ibm_watson) (2.2.3)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from ibm-cloud-sdk-core==3.*,>=3.3.6->ibm_watson) (2.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.5.3->ibm_watson) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->ibm_watson) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->ibm_watson) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->ibm_watson) (2024.8.30)

# %% [markdown]
# # 1. Authentication Setup

# %%
from ibm_watson import TextToSpeechV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
import json

# %%
apikey = 't5o9yO-ZnXaN39aTFwC3EWUiV_OCjppDh-1l1lVz3oNL'
url = 'https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b'

# %%
# Setup IBM Watson Text-to-Speech Service
authenticator = IAMAuthenticator(apikey)
tts = TextToSpeechV1(authenticator=authenticator)
tts.set_service_url(url)

# %% [markdown]
# # 2. List Available Voices

# %%
def list_voices():
    voices = tts.list_voices().get_result()
    print(json.dumps(voices, indent=2))

list_voices()
# Out:
# {
#   "voices": [
#     {
#       "name": "es-LA_DanielaExpressive",
#       "language": "es-LA",
#       "gender": "female",
#       "description": "Daniela: Latin American Spanish American (espa\\xF1ol latinoamericano) female voice. Dnn E2E technology with conversational and expressive capabilities.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/es-LA_DanielaExpressive"
#     },
#     {
#       "name": "en-AU_HeidiExpressive",
#       "language": "en-AU",
#       "gender": "female",
#       "description": "Heidi: Australian English female voice. Dnn E2E technology with conversational and expressive capabilities.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-AU_HeidiExpressive"
#     },
#     {
#       "name": "en-US_LisaExpressive",
#       "language": "en-US",
#       "gender": "female",
#       "description": "Lisa: American English female voice. Dnn E2E technology with conversational and expressive capabilities.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-US_LisaExpressive"
#     },
#     {
#       "name": "en-US_MichaelExpressive",
#       "language": "en-US",
#       "gender": "male",
#       "description": "Michael: American English male voice. Dnn E2E technology with conversational and expressive capabilities.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-US_MichaelExpressive"
#     },
#     {
#       "name": "en-US_AllisonExpressive",
#       "language": "en-US",
#       "gender": "female",
#       "description": "Allison: American English female voice. Dnn E2E technology with conversational and expressive capabilities.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-US_AllisonExpressive"
#     },
#     {
#       "name": "fr-FR_ReneeVoice",
#       "language": "fr-FR",
#       "gender": "female",
#       "description": "Renee: French (fran\u00e7ais) female voice.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/fr-FR_ReneeVoice"
#     },
#     {
#       "name": "de-DE_BirgitVoice",
#       "language": "de-DE",
#       "gender": "female",
#       "description": "Birgit: Standard German (Standarddeutsch) female voice.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/de-DE_BirgitVoice"
#     },
#     {
#       "name": "en-AU_JackExpressive",
#       "language": "en-AU",
#       "gender": "male",
#       "description": "Jack: Australian English male voice. Dnn E2E technology with conversational and expressive capabilities.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-AU_JackExpressive"
#     },
#     {
#       "name": "en-US_EmmaExpressive",
#       "language": "en-US",
#       "gender": "female",
#       "description": "Emma: American English female voice. Dnn E2E technology with conversational and expressive capabilities.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-US_EmmaExpressive"
#     },
#     {
#       "name": "en-US_AllisonVoice",
#       "language": "en-US",
#       "gender": "female",
#       "description": "Allison: American English female voice.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": true
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-US_AllisonVoice"
#     },
#     {
#       "name": "en-US_MichaelVoice",
#       "language": "en-US",
#       "gender": "male",
#       "description": "Michael: American English male voice.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": true
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-US_MichaelVoice"
#     },
#     {
#       "name": "en-GB_KateVoice",
#       "language": "en-GB",
#       "gender": "female",
#       "description": "Kate: British English female voice.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-GB_KateVoice"
#     },
#     {
#       "name": "ko-KR_JinV3Voice",
#       "language": "ko-KR",
#       "gender": "female",
#       "description": "Jin: Korean female voice. Dnn technology. ",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/ko-KR_JinV3Voice"
#     },
#     {
#       "name": "de-DE_DieterVoice",
#       "language": "de-DE",
#       "gender": "male",
#       "description": "Dieter: Standard German (Standarddeutsch) male voice.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/de-DE_DieterVoice"
#     },
#     {
#       "name": "en-US_KevinV3Voice",
#       "language": "en-US",
#       "gender": "male",
#       "description": "Kevin: American English male voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-US_KevinV3Voice"
#     },
#     {
#       "name": "fr-FR_ReneeV3Voice",
#       "language": "fr-FR",
#       "gender": "female",
#       "description": "Renee: French (fran\u00e7ais) female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/fr-FR_ReneeV3Voice"
#     },
#     {
#       "name": "fr-CA_LouiseV3Voice",
#       "language": "fr-CA",
#       "gender": "female",
#       "description": "Louise: French Canadian female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/fr-CA_LouiseV3Voice"
#     },
#     {
#       "name": "en-US_AllisonV3Voice",
#       "language": "en-US",
#       "gender": "female",
#       "description": "Allison: American English female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-US_AllisonV3Voice"
#     },
#     {
#       "name": "es-US_SofiaVoice",
#       "language": "es-US",
#       "gender": "female",
#       "description": "Sofia: North American Spanish (espa\u00f1ol norteamericano) female voice.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/es-US_SofiaVoice"
#     },
#     {
#       "name": "en-US_OliviaV3Voice",
#       "language": "en-US",
#       "gender": "female",
#       "description": "Olivia: American English female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-US_OliviaV3Voice"
#     },
#     {
#       "name": "en-US_LisaVoice",
#       "language": "en-US",
#       "gender": "female",
#       "description": "Lisa: American English female voice.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": true
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-US_LisaVoice"
#     },
#     {
#       "name": "de-DE_BirgitV2Voice",
#       "language": "de-DE",
#       "gender": "female",
#       "description": "Birgit: Standard German (Standarddeutsch) female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/de-DE_BirgitV2Voice"
#     },
#     {
#       "name": "en-GB_JamesV3Voice",
#       "language": "en-GB",
#       "gender": "male",
#       "description": "James: British English male voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-GB_JamesV3Voice"
#     },
#     {
#       "name": "de-DE_BirgitV3Voice",
#       "language": "de-DE",
#       "gender": "female",
#       "description": "Birgit: Standard German (Standarddeutsch) female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/de-DE_BirgitV3Voice"
#     },
#     {
#       "name": "pt-BR_IsabelaVoice",
#       "language": "pt-BR",
#       "gender": "female",
#       "description": "Isabela: Brazilian Portuguese (portugu\u00eas brasileiro) female voice.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/pt-BR_IsabelaVoice"
#     },
#     {
#       "name": "en-GB_KateV3Voice",
#       "language": "en-GB",
#       "gender": "female",
#       "description": "Kate: British English female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-GB_KateV3Voice"
#     },
#     {
#       "name": "en-US_HenryV3Voice",
#       "language": "en-US",
#       "gender": "male",
#       "description": "Henry: American English male voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-US_HenryV3Voice"
#     },
#     {
#       "name": "ja-JP_EmiV3Voice",
#       "language": "ja-JP",
#       "gender": "female",
#       "description": "Emi: Japanese (\u65e5\u672c\u8a9e) female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/ja-JP_EmiV3Voice"
#     },
#     {
#       "name": "es-LA_SofiaV3Voice",
#       "language": "es-LA",
#       "gender": "female",
#       "description": "Sofia: Latin American Spanish (espa\u00f1ol latinoamericano) female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/es-LA_SofiaV3Voice"
#     },
#     {
#       "name": "it-IT_FrancescaVoice",
#       "language": "it-IT",
#       "gender": "female",
#       "description": "Francesca: Italian (italiano) female voice.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/it-IT_FrancescaVoice"
#     },
#     {
#       "name": "es-ES_EnriqueV3Voice",
#       "language": "es-ES",
#       "gender": "male",
#       "description": "Enrique: Castilian Spanish (espa\u00f1ol castellano) male voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/es-ES_EnriqueV3Voice"
#     },
#     {
#       "name": "de-DE_DieterV3Voice",
#       "language": "de-DE",
#       "gender": "male",
#       "description": "Dieter: Standard German (Standarddeutsch) male voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/de-DE_DieterV3Voice"
#     },
#     {
#       "name": "es-ES_EnriqueVoice",
#       "language": "es-ES",
#       "gender": "male",
#       "description": "Enrique: Castilian Spanish (espa\u00f1ol castellano) male voice.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/es-ES_EnriqueVoice"
#     },
#     {
#       "name": "es-LA_SofiaVoice",
#       "language": "es-LA",
#       "gender": "female",
#       "description": "Sofia: Latin American Spanish (espa\u00f1ol latinoamericano) female voice.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/es-LA_SofiaVoice"
#     },
#     {
#       "name": "en-US_LisaV2Voice",
#       "language": "en-US",
#       "gender": "female",
#       "description": "Lisa: American English female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-US_LisaV2Voice"
#     },
#     {
#       "name": "pt-BR_IsabelaV3Voice",
#       "language": "pt-BR",
#       "gender": "female",
#       "description": "Isabela: Brazilian Portuguese (portugu\u00eas brasileiro) female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/pt-BR_IsabelaV3Voice"
#     },
#     {
#       "name": "it-IT_FrancescaV2Voice",
#       "language": "it-IT",
#       "gender": "female",
#       "description": "Francesca: Italian (italiano) female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/it-IT_FrancescaV2Voice"
#     },
#     {
#       "name": "en-US_MichaelV2Voice",
#       "language": "en-US",
#       "gender": "male",
#       "description": "Michael: American English male voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-US_MichaelV2Voice"
#     },
#     {
#       "name": "es-ES_LauraV3Voice",
#       "language": "es-ES",
#       "gender": "female",
#       "description": "Laura: Castilian Spanish (espa\u00f1ol castellano) female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/es-ES_LauraV3Voice"
#     },
#     {
#       "name": "en-US_MichaelV3Voice",
#       "language": "en-US",
#       "gender": "male",
#       "description": "Michael: American English male voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-US_MichaelV3Voice"
#     },
#     {
#       "name": "nl-NL_MerelV3Voice",
#       "language": "nl-NL",
#       "gender": "female",
#       "description": "Merel: Dutch female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/nl-NL_MerelV3Voice"
#     },
#     {
#       "name": "it-IT_FrancescaV3Voice",
#       "language": "it-IT",
#       "gender": "female",
#       "description": "Francesca: Italian (italiano) female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/it-IT_FrancescaV3Voice"
#     },
#     {
#       "name": "fr-FR_NicolasV3Voice",
#       "language": "fr-FR",
#       "gender": "male",
#       "description": "Nicolas: French (fran\u00e7ais) male voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/fr-FR_NicolasV3Voice"
#     },
#     {
#       "name": "en-US_LisaV3Voice",
#       "language": "en-US",
#       "gender": "female",
#       "description": "Lisa: American English female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-US_LisaV3Voice"
#     },
#     {
#       "name": "es-US_SofiaV3Voice",
#       "language": "es-US",
#       "gender": "female",
#       "description": "Sofia: North American Spanish (espa\u00f1ol norteamericano) female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/es-US_SofiaV3Voice"
#     },
#     {
#       "name": "en-GB_CharlotteV3Voice",
#       "language": "en-GB",
#       "gender": "female",
#       "description": "Charlotte: British English female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-GB_CharlotteV3Voice"
#     },
#     {
#       "name": "de-DE_ErikaV3Voice",
#       "language": "de-DE",
#       "gender": "female",
#       "description": "Erika: Standard German (Standarddeutsch) female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/de-DE_ErikaV3Voice"
#     },
#     {
#       "name": "ja-JP_EmiVoice",
#       "language": "ja-JP",
#       "gender": "female",
#       "description": "Emi: Japanese (\u65e5\u672c\u8a9e) female voice.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/ja-JP_EmiVoice"
#     },
#     {
#       "name": "es-ES_LauraVoice",
#       "language": "es-ES",
#       "gender": "female",
#       "description": "Laura: Castilian Spanish (espa\u00f1ol castellano) female voice.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/es-ES_LauraVoice"
#     },
#     {
#       "name": "de-DE_DieterV2Voice",
#       "language": "de-DE",
#       "gender": "male",
#       "description": "Dieter: Standard German (Standarddeutsch) male voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/de-DE_DieterV2Voice"
#     },
#     {
#       "name": "en-US_AllisonV2Voice",
#       "language": "en-US",
#       "gender": "female",
#       "description": "Allison: American English female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-US_AllisonV2Voice"
#     },
#     {
#       "name": "en-US_EmilyV3Voice",
#       "language": "en-US",
#       "gender": "female",
#       "description": "Emily: American English female voice. Dnn technology.",
#       "customizable": true,
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/dc59ca9c-41d1-4790-867d-b221ef525e7b/v1/voices/en-US_EmilyV3Voice"
#     }
#   ]
# }

# %% [markdown]
# ## 3. Convert Text to Speech

# %%
def convert_text_to_speech(text, voice='en-US_AllisonV3Voice', output_filename='output.mp3'):
    """Convert the given text to speech and save it to an audio file."""
    with open(output_filename, 'wb') as audio_file:
        response = tts.synthesize(text, accept='audio/mp3', voice=voice).get_result()
        audio_file.write(response.content)
    print(f"Audio content saved to {output_filename}")

# %%
# Adding more English voices
voices_to_test = [
    ('en-US_AllisonV3Voice', 'Hello from Allison!'),
    ('en-US_MichaelV3Voice', 'Hello from Michael!'),
    ('en-GB_JamesV3Voice', 'Hello from James!'),
    ('en-GB_KateV3Voice', 'Hello from Kate!'),
]

for voice, text in voices_to_test:
    with open(f'./speech_{voice}.mp3', 'wb') as audio_file:
        res = tts.synthesize(text, accept='audio/mp3', voice=voice).get_result()
        audio_file.write(res.content)

# %%
# Example usage
convert_text_to_speech('Hello World!', voice='en-US_AllisonV3Voice', output_filename='hello_world.mp3')
# Out:
# Audio content saved to hello_world.mp3

# %% [markdown]
# ## 4. Testing Different Voices

# %%
def test_multiple_voices():
    voices_to_test = [
        ('en-US_AllisonV3Voice', 'Hello from Allison!'),
        ('en-US_MichaelV3Voice', 'Hello from Michael!'),
        ('en-GB_JamesV3Voice', 'Hello from James!'),
        ('en-GB_KateV3Voice', 'Hello from Kate!'),
    ]
    for voice, text in voices_to_test:
        output_filename = f'./speech_{voice}.mp3'
        convert_text_to_speech(text, voice=voice, output_filename=output_filename)

# Test multiple voices
test_multiple_voices()
# Out:
# Audio content saved to ./speech_en-US_AllisonV3Voice.mp3
# Audio content saved to ./speech_en-US_MichaelV3Voice.mp3
# Audio content saved to ./speech_en-GB_JamesV3Voice.mp3
# Audio content saved to ./speech_en-GB_KateV3Voice.mp3

# %% [markdown]
# # 5. Reading Text from a File

# %%
def convert_file_to_speech(text_file, voice='en-GB_JamesV3Voice', output_filename='output.mp3'):
    """Read text from a file and convert it to speech."""
    with open(text_file, 'r') as f:
        text = f.read().replace('\n', '')
    convert_text_to_speech(text, voice=voice, output_filename=output_filename)

# %%
# Example usage
convert_file_to_speech('Test.txt', voice='en-GB_JamesV3Voice', output_filename='James.mp3')
# Out:
# Audio content saved to James.mp3

# %% [markdown]
# # 6. Convert French Text Example

# %%
def convert_french_text():
    frere_jacques = """
    Frère Jacques
    Dormez-vous?
    Sonnez les matines
    Ding, ding, dong
    """
    convert_text_to_speech(frere_jacques, voice='fr-FR_ReneeV3Voice', output_filename='frere.mp3')

# %%
# Convert French text
convert_french_text()
# Out:
# Audio content saved to frere.mp3
